# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import copy
import random
import time

class EVCSIndividual:

    '''
    individual of demand oriented method
    '''
    def __init__(self,data,ev_ct,ec_cp,ev_n):

        self.data=data  #候选数据
        self.evcs=np.zeros(ev_n)  #每个充电站的车数
        self.individual=[]
        self.fitness=[]
        self.ev_ct=ev_ct
        self.ev_cp=ec_cp
        self.ev_n=ev_n

    def GenerateIndividual(self):
        '''
        generate a random chromsome for genetic algorithm
        '''
        gene = list()    #问题的解，基因，种群中的个体：[0，...，city_size]
        for i in range(len(self.data)):
            ind=random.choices(self.data[i])
            copy_ind=copy.deepcopy(ind[0])
            copy_ind.append(i)
            gene.append(copy_ind)
        random.shuffle(gene)
        self.individual=gene

    def calculateFitness(self,cd_n=5):
        '''
        calculate the fitness of the indiviual
        '''
        ev_n=np.zeros((self.ev_n,cd_n))  #单位时间内每个电桩充电车数
        cd_wt=np.zeros((self.ev_n,cd_n)) #充电桩工作总时间
        cd_st=np.zeros((self.ev_n,cd_n)) #充电桩空闲时间
        st=0.   #电桩空闲总时间  
        qt=0.   #电车排队总时间 
        tt=0.   #充电总时间 到充电桩时间+排队时间+充电时间     
        cost=0. #充电总成本成本
        n=[]  
        x_n=0
        for i in range(len(self.individual)): #len(self.indiviual)
            cost+=self.individual[i][1]+self.ev_cp[self.individual[i][0]]*self.ev_ct[self.individual[i][2]]
            k=int(self.evcs[self.individual[i][0]]%cd_n)
            self.evcs[self.individual[i][0]]+=1
            if cd_wt[self.individual[i][0]][k]<60:
                ev_n[self.individual[i][0]][k]+=1
            if self.individual[i][1]<cd_wt[self.individual[i][0]][k]:
                tt+=cd_wt[self.individual[i][0]][k]+self.ev_ct[self.individual[i][0]]
                qt+=cd_wt[self.individual[i][0]][k]-self.individual[i][1]
                cd_wt[self.individual[i][0]][k]=cd_wt[self.individual[i][0]][k]+self.ev_ct[self.individual[i][0]]
                x_n+=1
            else:
                tt+=self.individual[i][1]+self.ev_ct[self.individual[i][0]]
                st+=self.individual[i][1]-cd_wt[self.individual[i][0]][k]
                cd_st[self.individual[i][0]][k]+=self.individual[i][1]-cd_wt[self.individual[i][0]][k]
                cd_wt[self.individual[i][0]][k]=self.individual[i][1]+self.ev_ct[self.individual[i][0]]
        revnue=0.
        t_ev_n=0
        t_st_v=0
        for i in range(self.ev_n):
            for j in range(cd_n):
                revnue+=(cd_wt[i][j]-cd_st[i][j])*self.ev_cp[i]
                t_ev_n+=ev_n[i][j]
                t_st_v+=cd_st[i][j]
        
        n.append(revnue)      #总收益  
        n.append(cost)        #总成本
        n.append(tt)          #总时间
        n.append(qt)          #总排队时间
        n.append(st)          #总空闲时间
        n.append(t_ev_n)      #单位时间每个充电桩充电电车总数
        self.fitness=np.array(n)

class GeneticAlgorithm:
    def __init__(self, t_c_l, ev_ct, ev_cp, n,c_rate=0.7, m_rate=0.3, pop_size=200, maxnum=200):
        self.pop_size = pop_size#50
        self.fitness = np.zeros(self.pop_size)#Pop_size 为50，种群个数，应该修改为参数，可传递任意种群个数
        self.c_rate = c_rate #交叉率，0.7，修改为可变参数
        self.m_rate = m_rate #变异率，0.05，修改为
        self.maxiternum = maxnum# 最大迭代次数
        self.population=[]
        self.bestfitness=0.   #最好的适应值
        self.besttruefitness=[] # 最好的真适应值
        self.bestIndex=0
        self.bestgene=np.array([])
        self.trace = np.zeros((self.maxiternum, 2))
        self.avefitness=0.
        self.data=t_c_l
        self.ev_ct=ev_ct
        self.ev_cp=ev_cp
        self.cs_n=n
        self.bestindividual=[]   #最好的个体
    
    def initialize(self):
        '''
        initialize the population of GA
        '''
        for i in range(0, int(self.pop_size)):
            ind = EVCSIndividual(self.data,self.ev_ct,self.ev_cp,self.cs_n)
            ind.GenerateIndividual()
            self.population.append(ind)
        
    def evaluation(self):
        '''
        evaluation the fitness of the population
        '''
        for i in range(0, int(self.pop_size)):
            self.population[i].calculateFitness()
            #self.fitness[i] = self.population[i].fitness
            self.fitness[i] = 0.3*(self.population[i].fitness[3]/40000)+0.4*(self.population[i].fitness[4]/3000)+0.3*(1-self.population[i].fitness[5]/899)
            
    def selection(self):
        for i in range(self.pop_size):
            if i != self.bestIndex and self.fitness[i] > self.avefitness:
                pi = self.cross(self.population[self.bestIndex].individual, self.population[i].individual)
                self.population[i].individual= self.mutate(pi)
                #print(self.population[i].indiviual)
                self.population[i].calculateFitness()
                #self.fitness[i] = self.population[i].fitness
                self.fitness[i] = 0.3*(self.population[i].fitness[3]/40000)+0.4*(self.population[i].fitness[4]/3000)+0.3*(1-self.population[i].fitness[5]/899)
    
    def crossoverMutation(self):
         for j in range(self.pop_size):
                #if j != self.bestIndex:
                r = np.random.randint(0, self.pop_size - 1)
                if j != r and j !=self.bestIndex :
                    nind = self.cross(self.population[j].individual, self.population[r].individual)    #交叉种群中第j,r个体的基因
                    self.population[j].individual = self.mutate(nind)    #突变种群中第j个体的基因
                    self.population[j].calculateFitness()
                    #self.fitness[j] = self.population[j].fitness
                    self.fitness[j] = 0.3*(self.population[j].fitness[3]/40000)+0.4*(self.population[j].fitness[4]/3000)+0.3*(1-self.population[j].fitness[5]/899)
       
    def cross(self, parent1, parent2):
        """crossover"""
        if np.random.rand() > self.c_rate:
            return parent1
        index1 = np.random.randint(0, len(parent1) - 1)
        index2 = np.random.randint(index1,  len(parent1)- 1)
        tempGene = parent2[index1:index2]  # 交叉的基因片段
        tempGene_t = pd.DataFrame(tempGene,columns=["0","1","2"])
        tempGene_c = list(tempGene_t["2"])
        newGene = []
        p1len = 0
        for g in parent1:
            if p1len == index1:
                newGene.extend(tempGene)  # 插入基因片段
            if g[2] not in tempGene_c:
                newGene.append(g)
            p1len += 1
        
        if len(newGene)!=len(parent1):
            ind = EVCSIndividual(self.data,self.ev_ct,self.ev_cp,self.cs_n)
            ind.GenerateIndividual()
            return ind.individual
        
        return newGene
    
    def mutate(self,gene):
        """mutation"""
        if np.random.rand() > self.m_rate:
            return gene
        index1 = np.random.randint(0, len(gene) - 1)
        index2 = np.random.randint(index1, len(gene) - 1)
        newGene = self.reverse_gen(gene, index1, index2)
        if len(newGene)!=len(gene):
            ind = EVCSIndividual(self.data,self.ev_ct,self.ev_cp,self.cs_n)
            ind.GenerateIndividual()
            return ind.individual
        return newGene
    
    def reverse_gen(self, gen, i, j):
        #函数：翻转基因中i到j之间的基因片段
        if i >= j:
            return gen
        if j > len(gen) - 1:
            return gen
        parent1 = copy.deepcopy(gen)
        tempGene = parent1[i:j]
        parent1[i:j]=tempGene[::-1]
        return parent1
    
    def solve(self):
        self.t = 0
        self.initialize()
        self.evaluation()
        self.bestfitness = np.min(self.fitness)
        self.bestIndex = np.argmin(self.fitness)
        self.bestgene = copy.deepcopy(self.population[self.bestIndex])
        self.besttruefitness=self.population[self.bestIndex].fitness
        self.bestindividual=self.population[self.bestIndex].individual
        self.avefitness = np.mean(self.fitness)
        self.trace[self.t, 0] = self.fitness[self.bestIndex]
        self.trace[self.t, 1] = self.avefitness
        print("Iteration:%d, fitness:%f, average fitness:%f, best individual:%s." % (
            self.t, self.trace[self.t, 0], self.trace[self.t, 1],str(self.bestgene.fitness)))

        while self.t < self.maxiternum - 1:
            self.t += 1
            self.selection()
            self.crossoverMutation()
            localbest = np.min(self.fitness)
            self.bestIndex = np.argmin(self.fitness)
            if localbest<self.bestfitness:
                self.bestfitness=localbest
                self.besttruefitness=self.population[self.bestIndex].fitness
                self.bestindividual=self.population[self.bestIndex].individual
            self.bestgene = copy.deepcopy(self.population[self.bestIndex])
            self.avefitness = np.mean(self.fitness)            
            self.trace[self.t, 0] = self.fitness[self.bestIndex]
            self.trace[self.t, 1] = self.avefitness
            print("Iteration:%d, fitness:%f, average fitness:%f, best individual:%s." % (
                self.t, self.trace[self.t, 0], self.trace[self.t, 1],str(self.bestgene.fitness)))
        print("True Best Fitness:",self.besttruefitness)
        print("Best Fitness:",self.bestfitness)
        print("Average of queuing time (minute):",self.besttruefitness[3]/899)
        print("Average of idle time (minute):",self.besttruefitness[4]/170)
        print("Number of charged EV within an hour:",int(self.besttruefitness[5]))
        print("Total cost of all EV:",self.besttruefitness[1])
        print("Total revenue of EVCS:",self.besttruefitness[0])
        print(list(self.trace[:,0]))
        
def main():
    #     dw = Draw()
    '''access dataset'''
    data = pd.read_csv("chargingstations.csv", delimiter=";", header=None).values  #读取34省市数据，以';'分割，dataframe
    cities = data[:, 1:]# 0行至最后一行，1列至最后一列
    cities_name = data[:, 0] #0行至最后一行，第0列
    city_size = data.shape[0]# shape属性返回包含行和列的元组
    locations = np.arange(cities.shape[0])    #问题的解，基因，种群中的个体：[0，...，city_size]

    ev_data_1000= pd.read_csv('ev_data_1000.csv').values 
    ev_x=ev_data_1000[:, 1:2]
    ev_x=[j for i in ev_x for j in i]
    ev_y=ev_data_1000[:, 2:3]
    ev_y=[j for i in ev_y for j in i]
    ev_ld=ev_data_1000[:, 3:4]
    ev_ld=[j for i in ev_ld for j in i]
    ev_ct=ev_data_1000[:, 4:5]
    ev_ct=[j for i in ev_ct for j in i]
    ev_cp_34= pd.read_csv('ev_cp_34.csv').values 
    ev_cp=ev_cp_34[:,1:]
    ev_cp=[j for i in ev_cp for j in i]

    '''charging stations'''
    t_c_l=[] #每个电车的候选充电站
    for i in range(1000):
        c_l=[]
        for j in range(34):
            d=np.sqrt((ev_x[i] - cities[j][0]) ** 2 + (ev_y[i] - cities[j][1]) ** 2)
            #d=ct_distance(ev_x[i],ev_y[i],cities[j])
            if d<ev_ld[i]:
                c=[]
                c.append(int(j))      # 充电站序号
                c.append(d)      # 距离充电站距离，也是行驶时间
                c_l.append(c)
        t_c_l.append(c_l)        

    for i in range(len(t_c_l)-1,-1,-1):
        if t_c_l[i]==[]:
            del ev_x[i]
            del ev_y[i]
            del ev_ld[i]
            del ev_ct[i]
            del t_c_l[i]
    GA=GeneticAlgorithm(t_c_l,ev_ct,ev_cp,len(cities))
#    GA.initialize()
    GA.solve()
        
#目前最优[ 16575.94745795 175006.78616601  55609.61504463  30785.9283487   2206.67604534    634.        ]
#适应值:0.594212,平均适应值:0.659067,最优结果:[ 16770.97487788 171025.98243471  55252.89521337  30548.93880873  2089.99381702    640.        ]
#适应值:0.508712,平均适应值:0.521612,最优结果:[ 16763.10019171 170352.63143501  53207.77215977  28552.77795326  1608.58002773    659.        ]
#适应值:0.507338,平均适应值:0.526123,最优结果:[ 16759.53057865 174122.93111212  52971.02862662  28044.18074583  1671.93032886    677.        ]
if __name__ == '__main__':
    start=time.time()
    main()
    end=time.time()
    print("Time consuming:",end-start)
# Out:
# Iteration:0, fitness:0.601889, average fitness:0.658294, best individual:[16723.88890692 28272.33421658 56537.91225432 31825.05232049
#   2080.79167614   642.        ].
# Iteration:1, fitness:0.588236, average fitness:0.634513, best individual:[16866.90530243 28175.90761584 55940.44619902 31341.68454704
#   2010.59246216   644.        ].
# Iteration:2, fitness:0.583067, average fitness:0.613126, best individual:[16899.37161191 28138.25297674 56254.33411015 31647.44529197
#   1927.09374215   633.        ].
# Iteration:3, fitness:0.570223, average fitness:0.602048, best individual:[16887.64082728 28108.69660133 55614.55197465 31078.00975812
#   1892.8276009    645.        ].
# Iteration:4, fitness:0.560173, average fitness:0.589268, best individual:[16843.27107423 28209.29486305 55137.07858645 30517.65388726
#   1858.98060423   649.        ].
# Iteration:5, fitness:0.558130, average fitness:0.577466, best individual:[16802.51250715 28245.17420251 55000.33920186 30361.28737627
#   1862.46777787   653.        ].
# Iteration:6, fitness:0.552406, average fitness:0.570945, best individual:[16799.56779208 28205.62379395 54636.15283479 30036.38030358
#   1847.82544486   657.        ].
# Iteration:7, fitness:0.550864, average fitness:0.568554, best individual:[16784.03079076 28226.10226708 54468.85484019 29863.69938439
#   1850.97778289   659.        ].
# Iteration:8, fitness:0.550502, average fitness:0.564960, best individual:[16784.03079076 28226.10226708 54467.62001097 29862.46455516
#   1848.33631831   659.        ].
# Iteration:9, fitness:0.543673, average fitness:0.563135, best individual:[16784.03079076 28226.10226708 54261.63425974 29656.47880394
#   1826.22146096   666.        ].
# Iteration:10, fitness:0.543040, average fitness:0.562672, best individual:[16784.03079076 28226.10226708 54239.31757677 29634.16212096
#   1822.73179923   666.        ].
# Iteration:11, fitness:0.541143, average fitness:0.560658, best individual:[16784.03079076 28226.10226708 54197.67640176 29592.52094595
#   1810.847956     666.        ].
# Iteration:12, fitness:0.540693, average fitness:0.559344, best individual:[16784.03079076 28226.10226708 54186.65762828 29581.50217247
#   1808.09326263   666.        ].
# Iteration:13, fitness:0.540529, average fitness:0.557851, best individual:[16784.03079076 28226.10226708 54184.44370647 29579.28825066
#   1806.98630172   666.        ].
# Iteration:14, fitness:0.540112, average fitness:0.555009, best individual:[16784.03079076 28226.10226708 54176.40644211 29571.2509863
#   1804.30721361   666.        ].
# Iteration:15, fitness:0.540112, average fitness:0.554349, best individual:[16784.03079076 28226.10226708 54176.40644211 29571.2509863
#   1804.30721361   666.        ].
# Iteration:16, fitness:0.538331, average fitness:0.551254, best individual:[16775.56961031 28217.31974638 54117.03051808 29520.55791144
#   1798.80898224   668.        ].
# Iteration:17, fitness:0.537054, average fitness:0.549298, best individual:[16775.56961031 28217.31974638 54045.80761893 29449.33501228
#   1785.73150533   665.        ].
# Iteration:18, fitness:0.534159, average fitness:0.548157, best individual:[16775.56961031 28217.31974638 53988.38185188 29391.90924524
#   1769.74795729   666.        ].
# Iteration:19, fitness:0.533927, average fitness:0.550649, best individual:[16775.56961031 28217.31974638 53988.97486442 29392.50225778
#   1767.97698648   666.        ].
# Iteration:20, fitness:0.530930, average fitness:0.545748, best individual:[16775.56961031 28217.31974638 53917.16939992 29320.69679328
#   1754.54328759   668.        ].
# Iteration:21, fitness:0.529607, average fitness:0.545909, best individual:[16775.56961031 28217.31974638 53886.6981005  29290.22549385
#   1746.33140031   668.        ].
# Iteration:22, fitness:0.527999, average fitness:0.546148, best individual:[16775.56961031 28217.31974638 53832.18116772 29235.70856107
#   1737.34004686   668.        ].
# Iteration:23, fitness:0.527350, average fitness:0.542451, best individual:[16775.56961031 28217.31974638 53819.70025117 29223.22764453
#   1733.17974135   668.        ].
# Iteration:24, fitness:0.526914, average fitness:0.541319, best individual:[16775.56961031 28217.31974638 53811.30305281 29214.83044616
#   1730.38067522   668.        ].
# Iteration:25, fitness:0.526614, average fitness:0.537921, best individual:[16774.09369139 28206.2332848  53800.50489205 29219.3309624
#   1730.38067522   669.        ].
# Iteration:26, fitness:0.525070, average fitness:0.535000, best individual:[16775.56961031 28217.31974638 53768.72420796 29172.25160131
#   1721.44454971   669.        ].
# Iteration:27, fitness:0.524880, average fitness:0.535580, best individual:[16774.09369139 28206.2332848  53760.53315739 29179.35922774
#   1722.124158     670.        ].
# Iteration:28, fitness:0.523860, average fitness:0.539273, best individual:[16775.56961031 28217.31974638 53740.47796057 29144.00535392
#   1713.96011699   669.        ].
# Iteration:29, fitness:0.523860, average fitness:0.537132, best individual:[16775.56961031 28217.31974638 53740.47796057 29144.00535392
#   1713.96011699   669.        ].
# Iteration:30, fitness:0.523746, average fitness:0.536465, best individual:[16775.56961031 28217.31974638 53740.39796075 29143.92535411
#   1713.10954825   669.        ].
# Iteration:31, fitness:0.523446, average fitness:0.536585, best individual:[16774.09369139 28206.2332848  53729.59979999 29148.42587034
#   1713.10954825   670.        ].
# Iteration:32, fitness:0.523446, average fitness:0.535965, best individual:[16774.09369139 28206.2332848  53729.59979999 29148.42587034
#   1713.10954825   670.        ].
# Iteration:33, fitness:0.520777, average fitness:0.535534, best individual:[16774.09369139 28206.2332848  53648.52043162 29067.34650197
#   1700.1566714    671.        ].
# Iteration:34, fitness:0.520341, average fitness:0.534824, best individual:[16774.09369139 28206.2332848  53640.12323326 29058.9493036
#   1697.35760528   671.        ].
# Iteration:35, fitness:0.519337, average fitness:0.535034, best individual:[16774.09369139 28206.2332848  53622.77583634 29041.60190668
#   1693.30732718   672.        ].
# Iteration:36, fitness:0.518941, average fitness:0.532650, best individual:[16774.09369139 28206.2332848  53616.87859996 29035.70467031
#   1690.66843005   672.        ].
# Iteration:37, fitness:0.518787, average fitness:0.534779, best individual:[16775.56961031 28217.31974638 53607.55230442 29011.07969778
#   1688.39880886   671.        ].
# Iteration:38, fitness:0.518752, average fitness:0.534635, best individual:[16774.09369139 28206.2332848  53608.53845954 29027.36452989
#   1689.72290176   672.        ].
# Iteration:39, fitness:0.518395, average fitness:0.532442, best individual:[16774.09369139 28206.2332848  53593.11964696 29011.94571731
#   1687.91294917   672.        ].
# Iteration:40, fitness:0.518254, average fitness:0.531084, best individual:[16775.56961031 28217.31974638 53594.02264305 28997.55003641
#   1685.15917176   671.        ].
# Iteration:41, fitness:0.517978, average fitness:0.528185, best individual:[16775.56961031 28217.31974638 53587.25142103 28990.77881438
#   1683.46636625   671.        ].
# Iteration:42, fitness:0.517978, average fitness:0.530676, best individual:[16775.56961031 28217.31974638 53587.25142103 28990.77881438
#   1683.46636625   671.        ].
# Iteration:43, fitness:0.517142, average fitness:0.531026, best individual:[16775.56961031 28217.31974638 53576.62445118 28980.15184454
#   1677.79562347   671.        ].
# Iteration:44, fitness:0.517142, average fitness:0.530610, best individual:[16775.56961031 28217.31974638 53576.62445118 28980.15184454
#   1677.79562347   671.        ].
# Iteration:45, fitness:0.516985, average fitness:0.531229, best individual:[16775.56961031 28217.31974638 53573.13667902 28976.66407237
#   1676.8178451    671.        ].
# Iteration:46, fitness:0.516056, average fitness:0.529456, best individual:[16775.56961031 28217.31974638 53551.39005172 28954.91744508
#   1671.07226691   671.        ].
# Iteration:47, fitness:0.516056, average fitness:0.529353, best individual:[16775.56961031 28217.31974638 53551.39005172 28954.91744508
#   1671.07226691   671.        ].
# Iteration:48, fitness:0.516056, average fitness:0.527369, best individual:[16775.56961031 28217.31974638 53551.39005172 28954.91744508
#   1671.07226691   671.        ].
# Iteration:49, fitness:0.516056, average fitness:0.530474, best individual:[16775.56961031 28217.31974638 53551.39005172 28954.91744508
#   1671.07226691   671.        ].
# Iteration:50, fitness:0.516056, average fitness:0.533181, best individual:[16775.56961031 28217.31974638 53551.39005172 28954.91744508
#   1671.07226691   671.        ].
# Iteration:51, fitness:0.516056, average fitness:0.532073, best individual:[16775.56961031 28217.31974638 53551.39005172 28954.91744508
#   1671.07226691   671.        ].
# Iteration:52, fitness:0.515967, average fitness:0.531019, best individual:[16775.56961031 28217.31974638 53549.67671285 28953.20410621
#   1670.50115395   671.        ].
# Iteration:53, fitness:0.515967, average fitness:0.529287, best individual:[16775.56961031 28217.31974638 53549.67671285 28953.20410621
#   1670.50115395   671.        ].
# Iteration:54, fitness:0.515967, average fitness:0.528455, best individual:[16775.56961031 28217.31974638 53549.67671285 28953.20410621
#   1670.50115395   671.        ].
# Iteration:55, fitness:0.515885, average fitness:0.530984, best individual:[16775.56961031 28217.31974638 53548.56783872 28952.09523208
#   1669.94671689   671.        ].
# Iteration:56, fitness:0.515885, average fitness:0.529640, best individual:[16775.56961031 28217.31974638 53548.56783872 28952.09523208
#   1669.94671689   671.        ].
# Iteration:57, fitness:0.515885, average fitness:0.533716, best individual:[16775.56961031 28217.31974638 53548.56783872 28952.09523208
#   1669.94671689   671.        ].
# Iteration:58, fitness:0.515885, average fitness:0.532303, best individual:[16775.56961031 28217.31974638 53548.56783872 28952.09523208
#   1669.94671689   671.        ].
# Iteration:59, fitness:0.515885, average fitness:0.530548, best individual:[16775.56961031 28217.31974638 53548.56783872 28952.09523208
#   1669.94671689   671.        ].
# Iteration:60, fitness:0.515874, average fitness:0.529376, best individual:[16775.56961031 28217.31974638 53548.31452173 28951.84191508
#   1669.88338764   671.        ].
# Iteration:61, fitness:0.515582, average fitness:0.528142, best individual:[16775.56961031 28217.31974638 53542.6916593  28946.21905266
#   1668.00910016   671.        ].
# Iteration:62, fitness:0.515582, average fitness:0.530445, best individual:[16775.56961031 28217.31974638 53542.6916593  28946.21905266
#   1668.00910016   671.        ].
# Iteration:63, fitness:0.515582, average fitness:0.529240, best individual:[16775.56961031 28217.31974638 53542.6916593  28946.21905266
#   1668.00910016   671.        ].
# Iteration:64, fitness:0.515582, average fitness:0.529292, best individual:[16775.56961031 28217.31974638 53542.6916593  28946.21905266
#   1668.00910016   671.        ].
# Iteration:65, fitness:0.515011, average fitness:0.528838, best individual:[16775.56961031 28217.31974638 53539.45877817 28942.98617153
#   1668.90890298   673.        ].
# Iteration:66, fitness:0.514514, average fitness:0.530233, best individual:[16775.56961031 28217.31974638 53529.90520375 28933.4325971
#   1665.72437817   673.        ].
# Iteration:67, fitness:0.514514, average fitness:0.529562, best individual:[16775.56961031 28217.31974638 53529.90520375 28933.4325971
#   1665.72437817   673.        ].
# Iteration:68, fitness:0.514514, average fitness:0.527227, best individual:[16775.56961031 28217.31974638 53529.90520375 28933.4325971
#   1665.72437817   673.        ].
# Iteration:69, fitness:0.514201, average fitness:0.527232, best individual:[16775.56961031 28217.31974638 53523.87274729 28927.40014065
#   1663.71355936   673.        ].
# Iteration:70, fitness:0.514201, average fitness:0.525682, best individual:[16775.56961031 28217.31974638 53523.87274729 28927.40014065
#   1663.71355936   673.        ].
# Iteration:71, fitness:0.514191, average fitness:0.528624, best individual:[16775.56961031 28217.31974638 53523.6194303  28927.14682366
#   1663.65023011   673.        ].
# Iteration:72, fitness:0.514191, average fitness:0.530283, best individual:[16775.56961031 28217.31974638 53523.6194303  28927.14682366
#   1663.65023011   673.        ].
# Iteration:73, fitness:0.514191, average fitness:0.528990, best individual:[16775.56961031 28217.31974638 53523.6194303  28927.14682366
#   1663.65023011   673.        ].
# Iteration:74, fitness:0.514191, average fitness:0.530666, best individual:[16775.56961031 28217.31974638 53523.6194303  28927.14682366
#   1663.65023011   673.        ].
# Iteration:75, fitness:0.514102, average fitness:0.533555, best individual:[16775.56961031 28217.31974638 53521.90609143 28925.43348479
#   1663.07911715   673.        ].
# Iteration:76, fitness:0.514102, average fitness:0.532606, best individual:[16775.56961031 28217.31974638 53521.90609143 28925.43348479
#   1663.07911715   673.        ].
# Iteration:77, fitness:0.514102, average fitness:0.529583, best individual:[16775.56961031 28217.31974638 53521.90609143 28925.43348479
#   1663.07911715   673.        ].
# Iteration:78, fitness:0.514102, average fitness:0.527780, best individual:[16775.56961031 28217.31974638 53521.90609143 28925.43348479
#   1663.07911715   673.        ].
# Iteration:79, fitness:0.513936, average fitness:0.528191, best individual:[16775.56961031 28217.31974638 53518.70918397 28922.23657732
#   1662.01348133   673.        ].
# Iteration:80, fitness:0.513936, average fitness:0.527650, best individual:[16775.56961031 28217.31974638 53518.70918397 28922.23657732
#   1662.01348133   673.        ].
# Iteration:81, fitness:0.513936, average fitness:0.527710, best individual:[16775.56961031 28217.31974638 53518.70918397 28922.23657732
#   1662.01348133   673.        ].
# Iteration:82, fitness:0.513859, average fitness:0.527632, best individual:[16775.56961031 28217.31974638 53515.29494649 28918.82233984
#   1661.62849383   673.        ].
# Iteration:83, fitness:0.513567, average fitness:0.525903, best individual:[16775.56961031 28217.31974638 53509.67208406 28913.19947742
#   1659.75420635   673.        ].
# Iteration:84, fitness:0.513567, average fitness:0.524520, best individual:[16775.56961031 28217.31974638 53509.67208406 28913.19947742
#   1659.75420635   673.        ].
# Iteration:85, fitness:0.513567, average fitness:0.526536, best individual:[16775.56961031 28217.31974638 53509.67208406 28913.19947742
#   1659.75420635   673.        ].
# Iteration:86, fitness:0.513567, average fitness:0.522873, best individual:[16775.56961031 28217.31974638 53509.67208406 28913.19947742
#   1659.75420635   673.        ].
# Iteration:87, fitness:0.513567, average fitness:0.525573, best individual:[16775.56961031 28217.31974638 53509.67208406 28913.19947742
#   1659.75420635   673.        ].
# Iteration:88, fitness:0.513567, average fitness:0.528186, best individual:[16775.56961031 28217.31974638 53509.67208406 28913.19947742
#   1659.75420635   673.        ].
# Iteration:89, fitness:0.513567, average fitness:0.528595, best individual:[16775.56961031 28217.31974638 53509.67208406 28913.19947742
#   1659.75420635   673.        ].
# Iteration:90, fitness:0.512555, average fitness:0.527296, best individual:[16775.56961031 28217.31974638 53473.24011439 28876.76750775
#   1656.71903571   674.        ].
# Iteration:91, fitness:0.511567, average fitness:0.523570, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:92, fitness:0.511567, average fitness:0.529250, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:93, fitness:0.511567, average fitness:0.527533, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:94, fitness:0.511567, average fitness:0.526726, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:95, fitness:0.511567, average fitness:0.524516, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:96, fitness:0.511567, average fitness:0.525445, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:97, fitness:0.511567, average fitness:0.523001, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:98, fitness:0.511567, average fitness:0.525985, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:99, fitness:0.511567, average fitness:0.523193, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:100, fitness:0.511567, average fitness:0.522841, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:101, fitness:0.511567, average fitness:0.523641, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:102, fitness:0.511567, average fitness:0.521921, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:103, fitness:0.511567, average fitness:0.525577, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:104, fitness:0.511567, average fitness:0.524897, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:105, fitness:0.511567, average fitness:0.521905, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:106, fitness:0.511567, average fitness:0.522205, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:107, fitness:0.511567, average fitness:0.525101, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:108, fitness:0.511567, average fitness:0.523126, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:109, fitness:0.511567, average fitness:0.522709, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:110, fitness:0.511567, average fitness:0.522392, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:111, fitness:0.511567, average fitness:0.524382, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:112, fitness:0.511567, average fitness:0.522458, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:113, fitness:0.511567, average fitness:0.523910, best individual:[16775.56961031 28217.31974638 53459.91662447 28863.44401782
#   1650.05729075   674.        ].
# Iteration:114, fitness:0.510712, average fitness:0.524839, best individual:[16775.56961031 28217.31974638 53409.37244602 28812.89983937
#   1648.99479869   675.        ].
# Iteration:115, fitness:0.510712, average fitness:0.522648, best individual:[16775.56961031 28217.31974638 53409.37244602 28812.89983937
#   1648.99479869   675.        ].
# Iteration:116, fitness:0.510712, average fitness:0.523171, best individual:[16775.56961031 28217.31974638 53409.37244602 28812.89983937
#   1648.99479869   675.        ].
# Iteration:117, fitness:0.510707, average fitness:0.520590, best individual:[16775.56961031 28217.31974638 53409.27271878 28812.80011213
#   1648.96155627   675.        ].
# Iteration:118, fitness:0.510513, average fitness:0.526847, best individual:[16775.56961031 28217.31974638 53405.53740066 28809.06479401
#   1647.71645023   675.        ].
# Iteration:119, fitness:0.510513, average fitness:0.525039, best individual:[16775.56961031 28217.31974638 53405.53740066 28809.06479401
#   1647.71645023   675.        ].
# Iteration:120, fitness:0.510333, average fitness:0.524448, best individual:[16775.56961031 28217.31974638 53401.11824361 28804.64563697
#   1646.61166097   675.        ].
# Iteration:121, fitness:0.510333, average fitness:0.525052, best individual:[16775.56961031 28217.31974638 53401.11824361 28804.64563697
#   1646.61166097   675.        ].
# Iteration:122, fitness:0.510333, average fitness:0.524151, best individual:[16775.56961031 28217.31974638 53401.11824361 28804.64563697
#   1646.61166097   675.        ].
# Iteration:123, fitness:0.510333, average fitness:0.525705, best individual:[16775.56961031 28217.31974638 53401.11824361 28804.64563697
#   1646.61166097   675.        ].
# Iteration:124, fitness:0.510333, average fitness:0.524647, best individual:[16775.56961031 28217.31974638 53401.11824361 28804.64563697
#   1646.61166097   675.        ].
# Iteration:125, fitness:0.510333, average fitness:0.522766, best individual:[16775.56961031 28217.31974638 53401.11824361 28804.64563697
#   1646.61166097   675.        ].
# Iteration:126, fitness:0.510333, average fitness:0.522659, best individual:[16775.56961031 28217.31974638 53401.11824361 28804.64563697
#   1646.61166097   675.        ].
# Iteration:127, fitness:0.510308, average fitness:0.521368, best individual:[16775.56961031 28217.31974638 53399.46169616 28802.98908951
#   1646.51711122   675.        ].
# Iteration:128, fitness:0.510300, average fitness:0.523007, best individual:[16775.56961031 28217.31974638 53399.3055934  28802.83298675
#   1646.46507697   675.        ].
# Iteration:129, fitness:0.510109, average fitness:0.527563, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:130, fitness:0.510109, average fitness:0.525967, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:131, fitness:0.510109, average fitness:0.523906, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:132, fitness:0.510109, average fitness:0.524921, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:133, fitness:0.510109, average fitness:0.525472, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:134, fitness:0.510109, average fitness:0.523478, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:135, fitness:0.510109, average fitness:0.523874, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:136, fitness:0.510109, average fitness:0.523827, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:137, fitness:0.510109, average fitness:0.527917, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:138, fitness:0.510109, average fitness:0.526921, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:139, fitness:0.510109, average fitness:0.526009, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:140, fitness:0.510109, average fitness:0.521291, best individual:[16775.56961031 28217.31974638 53395.6266508  28799.15404415
#   1645.23876277   675.        ].
# Iteration:141, fitness:0.510027, average fitness:0.521281, best individual:[16775.56961031 28217.31974638 53390.12145146 28793.64884482
#   1644.93861084   675.        ].
# Iteration:142, fitness:0.510027, average fitness:0.524504, best individual:[16775.56961031 28217.31974638 53390.12145146 28793.64884482
#   1644.93861084   675.        ].
# Iteration:143, fitness:0.509746, average fitness:0.520991, best individual:[16775.56961031 28217.31974638 53383.22950751 28786.75690087
#   1643.21562486   675.        ].
# Iteration:144, fitness:0.507856, average fitness:0.525973, best individual:[16775.56961031 28217.31974638 53332.51128365 28736.03867701
#   1631.89703274   675.        ].
# Iteration:145, fitness:0.507008, average fitness:0.522584, best individual:[16775.56961031 28217.31974638 53316.17971749 28719.70711085
#   1626.45317735   675.        ].
# Iteration:146, fitness:0.507008, average fitness:0.520776, best individual:[16775.56961031 28217.31974638 53316.17971749 28719.70711085
#   1626.45317735   675.        ].
# Iteration:147, fitness:0.507008, average fitness:0.522933, best individual:[16775.56961031 28217.31974638 53316.17971749 28719.70711085
#   1626.45317735   675.        ].
# Iteration:148, fitness:0.506337, average fitness:0.523016, best individual:[16775.56961031 28217.31974638 53303.26594257 28706.79333593
#   1622.14858571   675.        ].
# Iteration:149, fitness:0.505487, average fitness:0.524921, best individual:[16775.56961031 28217.31974638 53279.66694176 28683.19433512
#   1617.10073107   675.        ].
# Iteration:150, fitness:0.504956, average fitness:0.519267, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:151, fitness:0.504956, average fitness:0.519224, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:152, fitness:0.504956, average fitness:0.520183, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:153, fitness:0.504956, average fitness:0.521063, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:154, fitness:0.504956, average fitness:0.523186, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:155, fitness:0.504956, average fitness:0.520112, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:156, fitness:0.504956, average fitness:0.521327, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:157, fitness:0.504956, average fitness:0.521151, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:158, fitness:0.504956, average fitness:0.518973, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:159, fitness:0.504956, average fitness:0.520391, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:160, fitness:0.504956, average fitness:0.521396, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:161, fitness:0.504956, average fitness:0.519165, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:162, fitness:0.504956, average fitness:0.519086, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:163, fitness:0.504956, average fitness:0.517317, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:164, fitness:0.504956, average fitness:0.518705, best individual:[16775.56961031 28217.31974638 53269.44419504 28672.97158839
#   1613.69314883   675.        ].
# Iteration:165, fitness:0.504070, average fitness:0.520885, best individual:[16775.56961031 28217.31974638 53210.18794724 28613.71534059
#   1610.38400583   675.        ].
# Iteration:166, fitness:0.504070, average fitness:0.520666, best individual:[16775.56961031 28217.31974638 53210.18794724 28613.71534059
#   1610.38400583   675.        ].
# Iteration:167, fitness:0.504070, average fitness:0.525067, best individual:[16775.56961031 28217.31974638 53210.18794724 28613.71534059
#   1610.38400583   675.        ].
# Iteration:168, fitness:0.501863, average fitness:0.519054, best individual:[16775.56961031 28217.31974638 53154.59886786 28558.12626121
#   1599.45906327   676.        ].
# Iteration:169, fitness:0.501645, average fitness:0.519323, best individual:[16775.56961031 28217.31974638 53148.34212295 28551.8695163
#   1600.67529119   677.        ].
# Iteration:170, fitness:0.499912, average fitness:0.516568, best individual:[16775.56961031 28217.31974638 53114.97715312 28518.50454647
#   1589.55363458   677.        ].
# Iteration:171, fitness:0.499912, average fitness:0.515781, best individual:[16775.56961031 28217.31974638 53114.97715312 28518.50454647
#   1589.55363458   677.        ].
# Iteration:172, fitness:0.498523, average fitness:0.515264, best individual:[16775.56961031 28217.31974638 53082.02292883 28485.55032219
#   1585.99639995   679.        ].
# Iteration:173, fitness:0.498523, average fitness:0.515051, best individual:[16775.56961031 28217.31974638 53082.02292883 28485.55032219
#   1585.99639995   679.        ].
# Iteration:174, fitness:0.498523, average fitness:0.514753, best individual:[16775.56961031 28217.31974638 53082.02292883 28485.55032219
#   1585.99639995   679.        ].
# Iteration:175, fitness:0.498291, average fitness:0.511800, best individual:[16775.56961031 28217.31974638 53077.56218118 28481.08957454
#   1584.50948407   679.        ].
# Iteration:176, fitness:0.498291, average fitness:0.512640, best individual:[16775.56961031 28217.31974638 53077.56218118 28481.08957454
#   1584.50948407   679.        ].
# Iteration:177, fitness:0.498291, average fitness:0.512888, best individual:[16775.56961031 28217.31974638 53077.56218118 28481.08957454
#   1584.50948407   679.        ].
# Iteration:178, fitness:0.498291, average fitness:0.516208, best individual:[16775.56961031 28217.31974638 53077.56218118 28481.08957454
#   1584.50948407   679.        ].
# Iteration:179, fitness:0.497886, average fitness:0.517430, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:180, fitness:0.497886, average fitness:0.517269, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:181, fitness:0.497886, average fitness:0.518013, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:182, fitness:0.497886, average fitness:0.516352, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:183, fitness:0.497886, average fitness:0.516308, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:184, fitness:0.497886, average fitness:0.515964, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:185, fitness:0.497886, average fitness:0.515708, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:186, fitness:0.497886, average fitness:0.516004, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:187, fitness:0.497886, average fitness:0.516156, best individual:[16775.56961031 28217.31974638 53067.65143132 28471.17882468
#   1582.0317966    679.        ].
# Iteration:188, fitness:0.497553, average fitness:0.518390, best individual:[16775.56961031 28217.31974638 53052.11397525 28455.6413686
#   1580.40947257   679.        ].
# Iteration:189, fitness:0.496506, average fitness:0.516469, best individual:[16775.56961031 28217.31974638 53031.95163472 28435.47902807
#   1573.68869239   679.        ].
# Iteration:190, fitness:0.496506, average fitness:0.517218, best individual:[16775.56961031 28217.31974638 53031.95163472 28435.47902807
#   1573.68869239   679.        ].
# Iteration:191, fitness:0.496506, average fitness:0.517763, best individual:[16775.56961031 28217.31974638 53031.95163472 28435.47902807
#   1573.68869239   679.        ].
# Iteration:192, fitness:0.496506, average fitness:0.518382, best individual:[16775.56961031 28217.31974638 53031.95163472 28435.47902807
#   1573.68869239   679.        ].
# Iteration:193, fitness:0.495644, average fitness:0.516319, best individual:[16775.56961031 28217.31974638 53017.1972945  28420.72468786
#   1570.55622395   680.        ].
# Iteration:194, fitness:0.495644, average fitness:0.515209, best individual:[16775.56961031 28217.31974638 53017.1972945  28420.72468786
#   1570.55622395   680.        ].
# Iteration:195, fitness:0.495592, average fitness:0.513218, best individual:[16775.56961031 28217.31974638 53010.20894604 28413.73633939
#   1570.55622395   680.        ].
# Iteration:196, fitness:0.495592, average fitness:0.513308, best individual:[16775.56961031 28217.31974638 53010.20894604 28413.73633939
#   1570.55622395   680.        ].
# Iteration:197, fitness:0.495592, average fitness:0.513541, best individual:[16775.56961031 28217.31974638 53010.20894604 28413.73633939
#   1570.55622395   680.        ].
# Iteration:198, fitness:0.495592, average fitness:0.513953, best individual:[16775.56961031 28217.31974638 53010.20894604 28413.73633939
#   1570.55622395   680.        ].
# Iteration:199, fitness:0.495592, average fitness:0.515446, best individual:[16775.56961031 28217.31974638 53010.20894604 28413.73633939
#   1570.55622395   680.        ].
# True Best Fitness: [16775.56961031 28217.31974638 53010.20894604 28413.73633939
#   1570.55622395   680.        ]
# Best Fitness: 0.49559172040719324
# Average of queuing time (minute): 31.60593586139572
# Average of idle time (minute): 9.238566023246303
# Number of charged EV within an hour: 680
# Total cost of all EV: 28217.319746382374
# Total revenue of EVCS: 16775.569610310446
# [0.6018887402861834, 0.5882361785572107, 0.5830669667478472, 0.5702229320235891, 0.5601725136393397, 0.5581299048290419, 0.5524059742533074, 0.5508637708656818, 0.5505023143687637, 0.543672844779175, 0.543040181426058, 0.5411433601822797, 0.5406934269317831, 0.5405292277308266, 0.5401117364990131, 0.5401117364990131, 0.5383310326906078, 0.5370543097058477, 0.5341587725990208, 0.5339270907522591, 0.5309299816846672, 0.5296065286352502, 0.5279988045125449, 0.5273504902364577, 0.5269143024325296, 0.5266143521885797, 0.5250697735779322, 0.5248799911003438, 0.5238600023604167, 0.5238600023604165, 0.5237459931964542, 0.5234460429525043, 0.5234460429525042, 0.5207771933273229, 0.5203410055233948, 0.5193371588507047, 0.5189410766272095, 0.5187874772908763, 0.5187524551360615, 0.5183954870294767, 0.5182540532168547, 0.5179775616508027, 0.5179775616508026, 0.5171417603387726, 0.5171417603387726, 0.5169852315985289, 0.5160560548019357, 0.5160560548019356, 0.5160560548019355, 0.5160560548019355, 0.5160560548019354, 0.5160560548019353, 0.5159670563660853, 0.5159670563660853, 0.5159670563660853, 0.5158848148681187, 0.5158848148681184, 0.5158848148681184, 0.5158848148681182, 0.5158848148681182, 0.5158744710909381, 0.5155823946261194, 0.5155823946261194, 0.5155823946261194, 0.5155823946261194, 0.5150107134953246, 0.5145144583794159, 0.5145144583794158, 0.5145144583794157, 0.5142011057802574, 0.5142011057802574, 0.5141907620030771, 0.514190762003077, 0.5141907620030769, 0.5141907620030769, 0.5141017635672267, 0.5141017635672267, 0.5141017635672267, 0.5141017635672267, 0.513935701985187, 0.5139357019851869, 0.5139357019851869, 0.5138587635371881, 0.5135666870723696, 0.5135666870723695, 0.5135666870723695, 0.5135666870723695, 0.5135666870723695, 0.5135666870723694, 0.5135666870723693, 0.512555053765131, 0.5115668949291099, 0.5115668949291099, 0.5115668949291099, 0.5115668949291099, 0.5115668949291099, 0.5115668949291098, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5115668949291097, 0.5107124438668422, 0.5107124438668422, 0.5107124438668421, 0.5107072635906147, 0.5105132345661424, 0.5105132345661424, 0.5103327856533655, 0.5103327856533654, 0.5103327856533653, 0.5103327856533653, 0.5103327856533653, 0.5103327856533652, 0.5103327856533652, 0.5103077549141697, 0.5102996462430115, 0.5101085456134697, 0.5101085456134695, 0.5101085456134695, 0.5101085456134695, 0.5101085456134694, 0.5101085456134694, 0.5101085456134694, 0.5101085456134694, 0.5101085456134694, 0.5101085456134694, 0.5101085456134694, 0.5101085456134694, 0.510027236361973, 0.5100272363619729, 0.5097458153172959, 0.5078562830226249, 0.507007948891451, 0.507007948891451, 0.507007948891451, 0.5063371500276953, 0.505487110235869, 0.504956095336642, 0.5049560953366419, 0.5049560953366419, 0.5049560953366419, 0.5049560953366419, 0.5049560953366419, 0.5049560953366418, 0.5049560953366418, 0.5049560953366418, 0.5049560953366418, 0.5049560953366418, 0.5049560953366418, 0.5049560953366417, 0.5049560953366417, 0.5049560953366417, 0.5040704544115912, 0.504070454411591, 0.504070454411591, 0.5018631731922332, 0.5016447072132285, 0.49991158239138145, 0.4999115823913813, 0.4985227195274752, 0.4985227195274752, 0.49852271952747507, 0.49829100846889673, 0.49829100846889673, 0.49829100846889673, 0.49829100846889673, 0.49788631951622425, 0.4978863195162242, 0.49788631951622403, 0.49788631951622403, 0.497886319516224, 0.497886319516224, 0.497886319516224, 0.497886319516224, 0.497886319516224, 0.49755347872371514, 0.49650615714603175, 0.49650615714603163, 0.49650615714603163, 0.49650615714603163, 0.49564413302067334, 0.49564413302067334, 0.49559172040719335, 0.49559172040719324, 0.49559172040719324, 0.49559172040719324, 0.495591720407193 ...
# Time consuming: 538.2949228286743
